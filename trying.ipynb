# %%
import imageio
import pickle
import cv2
import matplotlib.pyplot as plt
with open('/home/darklord/Downloads/RHD_v1-1/RHD_published_v2/training/anno_training.pickle', 'rb') as file:
    data = pickle.load(file)
anno = data[43]
kp_coord_uv = anno['uv_vis'][:, :2]  # u, v coordinates of 42 hand keypoints, pixel
kp_visible = (anno['uv_vis'][:, 2] == 1)
image = cv2.imread('/home/darklord/Downloads/RHD_v1-1/RHD_published_v2/training/color/00043.png')
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.plot(kp_coord_uv[kp_visible, 0], kp_coord_uv[kp_visible, 1], 'ro')
